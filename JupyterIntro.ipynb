# %%
print("Hi there")
# Out:
# Hi there

# %%
print('Hi there friend')
userResponse = input('How are you today? ')
print('Your response was: ', userResponse, ' Thanks for letting me know')
# Out:
# Hi there friend
# How are you today? Good
# Your response was:  Good  Thanks for letting me know

# %%
print("What is your name?")
name = input()
print("Please choose 3 numbers:")
firstNumber = int(input("First number = "))
secondNumber = int(input("Second number = "))
thirdNumber = int(input("Third number = "))
fourthNumber = firstNumber+secondNumber
fifthNumber = fourthNumber*thirdNumber
print("Your name is {} and you chose {}, {}, and {} -- The results are {} and {}.".format(name, firstNumber, secondNumber, thirdNumber, fourthNumber, fifthNumber))
# Out:
# What is your name?
# Josh
# Please choose 3 numbers:
# First number = 5
# Second number = 6
# Third number = 7
# Your name is Josh and you chose 5, 6, and 7 -- The results are 11 and 77.
