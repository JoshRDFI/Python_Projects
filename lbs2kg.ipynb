# %%
k = 0.45359237
lbs = float(input("How many pounds do you need to convert to kilograms?"))
result = lbs * k
print("{} pounds is equal to {} kilograms.".format (lbs, result))
# Out:
# How many pounds do you need to convert to kilograms?75.65
# 75.65 pounds is equal to 34.3142627905 kilograms.
